# %% [markdown]
# SUMMARY-
# UnitedStates_COVID_19_dataset
#
# This is the data repository for the 2019 Novel Coronavirus Visual Dashboard operated by the Johns Hopkins University Center for Systems Science and Engineering (JHU CSSE). Also, Supported by ESRI Living Atlas Team and the Johns Hopkins University Applied Physics Lab (JHU APL).
#
# Coronavirus is a family of viruses that can cause illness, which can vary from common cold and cough to sometimes more severe disease. Middle East Respiratory Syndrome (MERS-CoV) and Severe Acute Respiratory Syndrome (SARS-CoV) were such severe cases with the world already has faced. SARS-CoV-2 (n-coronavirus) is the new virus of the coronavirus family, which first discovered in 2019, which has not been identified in humans before. It is a contiguous virus which started from Wuhan in December 2019. Which later declared as Pandemic by WHO due to high rate spreads throughout the world. Currently (on the date 20 May 2020), this leads to a total of 300K+ Deaths across the globe, including 90K+ deaths alone in USA.The dataset  is provided to identify the deaths and recovered cases.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
covid=pd.read_csv('/Users/drram/Documents/csse_covid_19_daily_reports_us.csv')
covid
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %%
covid.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %%
covid.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
covid.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
covid['Lat'].value_counts()
# Out:
#  41.5978    1
#  13.4443    1
#  31.1695    1
#  18.2208    1
# -14.2710    1
#  39.3185    1
#  43.3266    1
#  31.0545    1
#  44.2998    1
#  40.1500    1
#  35.7478    1
#  43.4525    1
#  36.1162    1
#  33.0406    1
#  39.8494    1
#  32.7416    1
#  47.4009    1
#  34.8405    1
#  32.3182    1
#  42.7560    1
#  38.4912    1
#  42.0115    1
#  41.1254    1
#  35.6301    1
#  44.0459    1
#  40.3495    1
#  47.5289    1
#  34.9697    1
#  42.2302    1
#  44.2685    1
#  15.0979    1
#  42.1657    1
#  38.8974    1
#  33.8569    1
#  44.2405    1
#  38.3135    1
#  61.3707    1
#  44.5720    1
#  18.3358    1
#  39.0639    1
#  38.4561    1
#  38.5266    1
#  46.9219    1
#  33.7298    1
#  27.7663    1
#  21.0943    1
#  39.0598    1
#  37.6681    1
#  35.5653    1
#  37.7693    1
#  44.6939    1
#  40.3888    1
#  40.5908    1
#  45.6945    1
#  41.6809    1
#  40.2989    1
# Name: Lat, dtype: int64

# %%
covid['Mortality_Rate'].value_counts()
# Out:
# 4.028152    1
# 4.479975    1
# 2.338902    1
# 4.448217    1
# 1.167315    1
# 7.384755    1
# 3.072626    1
# 3.783256    1
# 2.493766    1
# 1.240784    1
# 5.720339    1
# 6.818029    1
# 7.129119    1
# 4.763099    1
# 2.643857    1
# 2.138717    1
# 3.266683    1
# 4.263712    1
# 2.912621    1
# 3.999387    1
# 4.361479    1
# 2.759662    1
# 4.603894    1
# 3.788477    1
# 5.102870    1
# 4.912099    1
# 8.695652    1
# 6.050414    1
# 4.013194    1
# 5.466238    1
# 5.390015    1
# 1.101269    1
# 2.374515    1
# 6.367425    1
# 4.403318    1
# 7.001732    1
# 5.404917    1
# 3.583062    1
# 8.080819    1
# 5.016185    1
# 5.551700    1
# 4.435967    1
# 1.397713    1
# 2.516005    1
# 4.506164    1
# 9.523810    1
# 4.415327    1
# 5.011405    1
# 4.066421    1
# 9.545549    1
# 3.586073    1
# 5.698118    1
# 3.347280    1
# 3.246753    1
# 9.044775    1
# 1.656528    1
# 0.000000    1
# Name: Mortality_Rate, dtype: int64

# %%
covid['Province_State'].value_counts()
# Out:
# Virgin Islands              1
# Indiana                     1
# Kentucky                    1
# Guam                        1
# New York                    1
# Utah                        1
# Hawaii                      1
# Arkansas                    1
# Virginia                    1
# Pennsylvania                1
# District of Columbia        1
# California                  1
# Vermont                     1
# Ohio                        1
# Nebraska                    1
# Puerto Rico                 1
# Tennessee                   1
# Georgia                     1
# Rhode Island                1
# Montana                     1
# Florida                     1
# Iowa                        1
# North Dakota                1
# Minnesota                   1
# Connecticut                 1
# Oregon                      1
# Maryland                    1
# Texas                       1
# Alabama                     1
# Washington                  1
# 3591.383953     1
# 3435.108895     1
# 97.702058       1
# 3027.479921     1
# 2444.055121     1
# 2623.237570     1
# 3561.716796     1
# 5604.065930     1
# 3795.082856     1
# 5063.940017     1
# 5727.106946     1
# 2880.462020     1
# 2476.905835     1
# 7768.396797     1
# 3492.893832     1
# 2731.606784     1
# 5071.986102     1
# 2907.481174     1
# ...

# %%
covid['Hospitalization_Rate'].value_counts()
# Out:
# 7.972229     1
# 13.061686    1
# 17.856335    1
# 28.054438    1
# 8.579409     1
# 15.738420    1
# 21.562209    1
# 18.411936    1
# 18.030711    1
# 9.901758     1
# 14.992826    1
# 16.359364    1
# 13.598326    1
# 8.933819     1
# 12.752722    1
# 8.228329     1
# 11.438860    1
# 9.402795     1
# 6.778043     1
# 17.658649    1
# 17.468043    1
# 8.184176     1
# 17.348774    1
# 18.819911    1
# 10.693584    1
# 15.885351    1
# 12.022005    1
# 19.021310    1
# 11.126086    1
# 16.111235    1
# 24.611240    1
# 12.699285    1
# 10.000000    1
# Name: Hospitalization_Rate, dtype: int64

# %%
covid['Recovered'].value_counts()
# Out:
# 11783.0    1
# 1100.0     1
# 11637.0    1
# 8362.0     1
# 13.0       1
# 1302.0     1
# 1882.0     1
# 1275.0     1
# 336.0      1
# 440.0      1
# 2826.0     1
# 30341.0    1
# 473.0      1
# 1668.0     1
# 578.0      1
# 125.0      1
# 1059.0     1
# 6264.0     1
# 3478.0     1
# 3852.0     1
# 1406.0     1
# 1030.0     1
# 824.0      1
# 61.0       1
# 5451.0     1
# 3023.0     1
# 23945.0    1
# 28234.0    1
# 4266.0     1
# 4423.0     1
# 2993.0     1
# 3965.0     1
# 7681.0     1
# 3773.0     1
# 26249.0    1
# 61886.0    1
# 528.0      1
# 7728.0     1
# 12227.0    1
# 950.0      1
# 4523.0     1
# 352.0      1
# Name: Recovered, dtype: int64

# %%
covid['Deaths'].value_counts()
# Out:
# 0        2
# 407      2
# 377      1
# 2096     1
# 46       1
# 4525     1
# 299      1
# 3497     1
# 144      1
# 4770     1
# 1697     1
# 2123     1
# 283      1
# 538      1
# 1299     1
# 786      1
# 17       1
# 16       1
# 1037     1
# 138      1
# 11       1
# 522      1
# 393      1
# 6        1
# 5        1
# 3        1
# 2        1
# 305      1
# 125      1
# 1075     1
# 10749    1
# 376      1
# 2608     1
# 1781     1
# 747      1
# 54       1
# 107      1
# 481      1
# 28636    1
# 10       1
# 90       1
# 726      1
# 640      1
# 1426     1
# 77       1
# 73       1
# 202      1
# 3529     1
# 1864     1
# 69       1
# 5060     1
# 49       1
# 190      1
# 570      1
# 310      1
# 6066     1
# Name: Deaths, dtype: int64

# %%
sns.heatmap(covid.isnull())

# %% [markdown]
# ##FILLING OF NULL VALUES

# %%
#Filling of values numerical data
covid['Lat'].fillna(covid['Lat'].mean(), inplace=True)

# %%
covid['Long_'].fillna(covid['Long_'].mean(), inplace=True)
covid['Recovered'].fillna(covid['Recovered'].mean(), inplace=True)
covid['Incident_Rate'].fillna(covid['Incident_Rate'].mean(), inplace=True)
covid['People_Tested'].fillna(covid['People_Tested'].mean(), inplace=True)
covid['People_Hospitalized'].fillna(covid['People_Hospitalized'].mean(), inplace=True)
covid['Mortality_Rate'].fillna(covid['Mortality_Rate'].mean(), inplace=True)
covid['Testing_Rate'].fillna(covid['Testing_Rate'].mean(), inplace=True)
covid['Hospitalization_Rate'].fillna(covid['Hospitalization_Rate'].mean(), inplace=True)

# %%
covid.isnull().sum()
#null values are filled hence no null values present
# Out:
# Province_State          0
# Country_Region          0
# Last_Update             0
# Lat                     0
# Long_                   0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %% [markdown]
# ##statistical Analysis

# %%
#we need to change all the categorical values into numerical values
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in covid.columns:
    if covid.columns.dtype=='O':
        covid[i]=le.fit_transform(covid[i])

# %%
covid.describe()
# Out:
#        Province_State  Country_Region  Last_Update        Lat      Long_  \
# count       58.000000            58.0         58.0  58.000000  58.000000
# mean        28.500000             0.0          0.0  27.862069  28.051724
# std         16.886879             0.0          0.0  16.485452  16.456665
# min          0.000000             0.0          0.0   0.000000   0.000000
# 25%         14.250000             0.0          0.0  14.250000  14.250000
# 50%         28.500000             0.0          0.0  27.500000  28.500000
# 75%         42.750000             0.0          0.0  41.750000  41.750000
# max         57.000000             0.0          0.0  56.000000  56.000000
#
#        Confirmed     Deaths  Recovered     Active       FIPS  Incident_Rate  \
# count  58.000000  58.000000  58.000000  58.000000  58.000000      58.000000
# mean   28.500000  27.051724  23.586207  28.500000  28.500000      28.189655
# std    16.886879  16.424652  11.648408  16.886879  16.886879      16.515232
# ...

# %%
sns.heatmap(covid.corr())

# %%
covid.corr()
# Out:
#                       Province_State  Country_Region  Last_Update       Lat  \
# Province_State              1.000000             NaN          NaN  0.213132
# Country_Region                   NaN             NaN          NaN       NaN
# Last_Update                      NaN             NaN          NaN       NaN
# Lat                         0.213132             NaN          NaN  1.000000
# Long_                       0.149333             NaN          NaN -0.139201
# Confirmed                  -0.023963             NaN          NaN  0.074867
# Deaths                     -0.062019             NaN          NaN  0.071493
# Recovered                  -0.055029             NaN          NaN -0.061057
# Active                     -0.075764             NaN          NaN  0.070519
# FIPS                        0.714110             NaN          NaN -0.081988
# Incident_Rate              -0.127479             NaN          NaN  0.235940
# ...

# %% [markdown]
# #Observation-
# -Mortality_rate is negatively correlated with Lat, FIPS, UID and positively corr with rest all other attributes..
# - we can drop country_region and last_update..

# %%
covid.drop(['Country_Region','Last_Update'], axis=1, inplace=True)
covid.head()
# Out:
#    Province_State  Lat  Long_  Confirmed  Deaths  Recovered  Active  FIPS  \
# 0               0    9     28         32      31         31      40     0
# 1               1   56      2          6       5          4       5     1
# 2               2    0      0          0       0         31       0    51
# 3               3   12      9         35      36         23      36     2
# 4               4   15     22         19      16         24      16     3
#
#    Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  UID  \
# 0             29             32                   16              22    5
# 1              4              9                   25               9    6
# 2              0              0                   25              32    0
# 3             21             33                   18              38    7
# 4             15             21                    8               6    8
#
#    ISO3  Testing_Rate  Hospitalization_Rate
# ...

# %%
covid.pivot_table(values=(['Confirmed','Recovered']), index= 'Mortality_Rate')
# Out:
#                 Confirmed  Recovered
# Mortality_Rate
# 0                       2         31
# 1                      18         21
# 2                      24         27
# 3                      29         31
# 4                       9          7
# 5                      38         36
# 6                      19         24
# 7                      13         15
# 8                      27          6
# 9                       6          4
# 10                     36         34
# 11                      8          8
# 12                     50         41
# 13                      4         31
# 14                     14         17
# 15                      5          2
# 16                     44         28
# 17                      7          5
# 18                     40         35
# 19                     34         33
# 20                     26         25
# 21                     16         16
# 22                     32         31
# 23                     12         13
# ...

# %% [markdown]
# ##Further Analysis of the data

# %%
covid.columns
# Out:
# Index(['Province_State', 'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered',
#        'Active', 'FIPS', 'Incident_Rate', 'People_Tested',
#        'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3', 'Testing_Rate',
#        'Hospitalization_Rate'],
#       dtype='object')

# %%
covid.groupby(['Active']).mean()
# Out:
#         Province_State  Lat  Long_  Confirmed  Deaths  Recovered  FIPS  \
# Active
# 0                    2    0      0          0       0         31    51
# 1                   52    4     54          3       4          1    55
# 2                   39    2     56          1       1          0    53
# 3                   30   53     10          7       7          5    26
# 4                   14    1     55          5       3          2    52
# 5                    1   56      2          6       5          4     1
# 6                   15    5      1          8       8          8    11
# 7                    9   20     31          2       0         31    56
# 8                   51   46     48         10      11          9    45
# 9                   13   20     31          4       2         31    57
# 10                  57   43     11          9       6          7    50
# 11                  55   25     37         11      12         10    48
# ...

# %%
covid.groupby(['Deaths']).mean()
# Out:
#         Province_State   Lat  Long_  Confirmed  Recovered  Active  FIPS  \
# Deaths
# 0                  5.5  10.0   15.5        1.0       31.0     3.5  53.5
# 1                 39.0   2.0   56.0        1.0        0.0     2.0  53.0
# 2                 13.0  20.0   31.0        4.0       31.0     9.0  57.0
# 3                 14.0   1.0   55.0        5.0        2.0     4.0  52.0
# 4                 52.0   4.0   54.0        3.0        1.0     1.0  55.0
# 5                  1.0  56.0    2.0        6.0        4.0     5.0   1.0
# 6                 57.0  43.0   11.0        9.0        7.0    10.0  50.0
# 7                 30.0  53.0   10.0        7.0        5.0     3.0  26.0
# 8                 15.0   5.0    1.0        8.0        8.0     6.0  11.0
# 9                 47.0  49.0   15.0       18.0       21.0    17.0  41.0
# 10                38.0  55.0   14.0       13.0       15.0    13.0  34.0
# 11                51.0  46.0   48.0       10.0        9.0     8.0  45.0
# ...

# %%
covid.groupby(['Mortality_Rate']).mean()
# Out:
#                 Province_State  Lat  Long_  Confirmed  Deaths  Recovered  \
# Mortality_Rate
# 0                            9   20     31          2       0         31
# 1                           47   49     15         18       9         21
# 2                           50   32      8         24      15         27
# 3                           31   37     16         29      18         31
# 4                           57   43     11          9       6          7
# 5                           48   18     29         38      24         36
# 6                            4   15     22         19      16         24
# 7                           38   55     14         13      10         15
# 8                           20   26     19         27      21          6
# 9                            1   56      2          6       5          4
# 10                          19   40     21         36      28         34
# 11                          15    5      1          8       8          8
# ...

# %%
covid.groupby(['ISO3']).mean()
# Out:
#       Province_State        Lat      Long_  Confirmed     Deaths  Recovered  \
# ISO3
# 0           2.000000   0.000000   0.000000   0.000000   0.000000  31.000000
# 1          14.000000   1.000000  55.000000   5.000000   3.000000   2.000000
# 2          39.000000   2.000000  56.000000   1.000000   1.000000   0.000000
# 3          44.000000   3.000000  53.000000  15.000000  17.000000  31.000000
# 4          28.339623  30.301887  26.584906  30.735849  29.132075  24.584906
# 5          52.000000   4.000000  54.000000   3.000000   4.000000   1.000000
#
#          Active       FIPS  Incident_Rate  People_Tested  People_Hospitalized  \
# ISO3
# 0      0.000000  51.000000       0.000000       0.000000             25.00000
# 1      4.000000  52.000000       8.000000       4.000000             25.00000
# 2      2.000000  53.000000       1.000000       3.000000             25.00000
# 3     20.000000  54.000000       9.000000       2.000000             25.00000
# ...

# %% [markdown]
# ##Bivariate Analysis

# %%
sns.lineplot(x='Confirmed', y='Mortality_Rate', data= covid)

# %%
sns.scatterplot(x='Confirmed', y='Recovered', data= covid)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='ISO3',y='Deaths',hue='ISO3',size='Deaths', data=covid)
##death rates in USA is maximum as compared to others

# %%
sns.barplot(x='Active',y='Mortality_Rate', data=covid)

# %%
sns.barplot(x='ISO3',y='Mortality_Rate', data=covid)

# %%
sns.barplot(x='ISO3',y='Deaths', data=covid)

# %%
sns.swarmplot(x='Active',y='Mortality_Rate',data=covid)

# %% [markdown]
# ##Univariate Analysis

# %%
plt.figure(figsize=(15,10))
sns.countplot(covid.ISO3)

# %%
covid['Deaths'].plot.hist()

# %%
for i in covid.describe().columns:
    sns.boxplot(covid[i].dropna())
    plt.show()

# %%
col_list=covid.columns.values
plt.figure(figsize=(15,15))
for i in range (0,len(col_list)):
    if covid[col_list[i]].dtype!='O':
        plt.subplot(6,6,i+1)
        sns.boxplot(covid[col_list[i]], color='pink',orient='v')
        plt.tight_layout()

# %%
covid.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# ##Removing outliers and skewness

# %%
print("shape of data before removing outliers", covid.shape)

print()

print("Skewness of the dataset before removing outliers")
print(covid.skew())

from scipy.stats import zscore
z=np.abs(zscore(covid))


covid=covid[(z<3).all(axis=1)]

print('New Shape',covid.shape)
# Out:
# shape of data before removing outliers (58, 16)
#
# Skewness of the dataset before removing outliers
# Province_State          0.000000
# Lat                     0.023921
# Long_                  -0.009656
# Confirmed               0.000000
# Deaths                 -0.000447
# Recovered              -0.528942
# Active                  0.000000
# FIPS                    0.000000
# Incident_Rate          -0.030314
# People_Tested          -0.033286
# People_Hospitalized    -0.919808
# Mortality_Rate          0.000000
# UID                     0.000000
# ISO3                   -4.126625
# Testing_Rate           -0.026280
# Hospitalization_Rate   -0.084693
# dtype: float64
# New Shape (56, 16)

# %% [markdown]
# ##Splitting the data into target and input

# %%
x=covid.drop('Deaths', axis=1)
x.head()
# Out:
#    Province_State  Lat  Long_  Confirmed  Recovered  Active  FIPS  \
# 0               0    9     28         32         31      40     0
# 1               1   56      2          6          4       5     1
# 3               3   12      9         35         23      36     2
# 4               4   15     22         19         24      16     3
# 5               5   19      5         53         31      53     4
#
#    Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  UID  \
# 0             29             32                   16              22    5
# 1              4              9                   25               9    6
# 3             21             33                   18              38    7
# 4             15             21                    8               6    8
# 5             22             55                   25              25    9
#
#    ISO3  Testing_Rate  Hospitalization_Rate
# 0     4            25                    11
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x=pd.DataFrame(scaler.fit_transform(x))
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  0.129630  0.490909  0.553571  0.738095  0.696429  0.000000
# 1  0.017544  1.000000  0.018182  0.089286  0.095238  0.071429  0.017544
# 2  0.052632  0.185185  0.145455  0.607143  0.547619  0.625000  0.035088
# 3  0.070175  0.240741  0.381818  0.321429  0.571429  0.267857  0.052632
# 4  0.087719  0.314815  0.072727  0.928571  0.738095  0.928571  0.070175
#
#           7         8         9        10        11        12        13  \
# 0  0.509091  0.563636  0.484848  0.385965  0.054545  0.666667  0.446429
# 1  0.054545  0.145455  0.757576  0.157895  0.072727  0.666667  0.767857
# 2  0.363636  0.581818  0.545455  0.666667  0.090909  0.666667  0.071429
# 3  0.254545  0.363636  0.242424  0.105263  0.109091  0.666667  0.392857
# 4  0.381818  0.981818  0.757576  0.438596  0.127273  0.666667  0.500000
#
#          14
# 0  0.333333
# 1  0.515152
# 2  0.363636
# 3  0.272727
# 4  0.515152

# %%
y=pd.DataFrame(covid.Deaths)
y.head()
# Out:
#    Deaths
# 0      31
# 1       5
# 3      36
# 4      16
# 5      48

# %% [markdown]
# ##IMPORTING NECESSARY LIBRARIES

# %% [markdown]
# #since the target is continues type, so the regression algorithm will be used.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

def max_r2_score(reg,x,y):
    max_r2score=0
    for r_state in range(42,101):
        train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state,test_size=0.20)
        reg.fit(train_x,train_y)
        pred=reg.predict(test_x)
        r2score=r2_score(test_y,pred)
        print("The r2 score", r2score, "is achieved at r_state", r_state)
        if r2score>max_r2score:
            max_r2score=r2score
            final_r_state=r_state
    print("The maximum r2 score", max_r2score, "is achieved at r_state", final_r_state)
    return final_r_state

# %%
lr=LinearRegression()
max_r2_score(lr,x,y)
# Out:
# The r2 score 0.12035115036958477 is achieved at r_state 42
# The r2 score 0.34587054243324256 is achieved at r_state 43
# The r2 score 0.9748577044715573 is achieved at r_state 44
# The r2 score 0.9468846076986976 is achieved at r_state 45
# The r2 score 0.9641940472810164 is achieved at r_state 46
# The r2 score 0.8835487058255662 is achieved at r_state 47
# The r2 score 0.9766720206085013 is achieved at r_state 48
# The r2 score 0.9448162791724575 is achieved at r_state 49
# The r2 score -6.7027966799740035 is achieved at r_state 50
# The r2 score 0.6780007192626231 is achieved at r_state 51
# The r2 score 0.9687392200755502 is achieved at r_state 52
# The r2 score 0.9838005934889429 is achieved at r_state 53
# The r2 score 0.7995895103881776 is achieved at r_state 54
# The r2 score 0.9657000965379632 is achieved at r_state 55
# The r2 score 0.4580365396865088 is achieved at r_state 56
# The r2 score 0.9618728705502565 is achieved at r_state 57
# ...

# %%
#finalising the train test data
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=69,test_size=0.20)

# %%
#Lets check the cross val score for the same
from sklearn.model_selection import cross_val_score
lrcrossval=cross_val_score(lr,x,y,cv=5, scoring='r2').mean()
print("The cross val score of the linear regression is", lrcrossval)
# Out:
# The cross val score of the linear regression is -15.852906731030748

# %%
#We need to check the other regression model and their results.
#using GridSearchCV to select best parameter for the models
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
kn=KNeighborsRegressor()
parameters={'n_neighbors':(1,10)}
gdk=GridSearchCV(kn,parameters)
gdk.fit(train_x,train_y)
gdk.best_params_
# Out:
# {'n_neighbors': 10}

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
parameters={'criterion':('mse','friedman_mse','mae')}
gdd=GridSearchCV(dt,parameters)
gdd.fit(train_x,train_y)
gdd.best_params_
# Out:
# {'criterion': 'friedman_mse'}

# %%
from sklearn.svm import SVR
sv=SVR()
parameters={'kernel':('linear','rbf'), 'C':[1,10]}
gdsr=GridSearchCV(sv,parameters)
gdsr.fit(train_x,train_y)
gdsr.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
#testing the algorithms
score=[]
cv=[]
Mean=[]
Root=[]

models=[lr,KNeighborsRegressor(n_neighbors=10),DecisionTreeRegressor(criterion='mse'),SVR(C=10,kernel='linear')]

for i in models:
    i.fit(train_x,train_y)
    pred=i.predict(test_x)
    r2score=r2_score(test_y,pred)
    score.append(r2score)
    print(i)
    print("")
    print("The r2 score is ", r2score)
    cross=cross_val_score(i,x,y,cv=5,scoring='r2').mean()
    cv.append(cross)
    print("")
    print("The cross validation score is", cross)
    print()
    Meanerror=mean_absolute_error(test_y,pred)
    Mean.append(Meanerror)
    print("The mean absolute error is ", Meanerror)
    rmse=np.sqrt(Meanerror)
    Root.append(rmse)
    print()
    print("The root mean square error is", rmse)
    print()
    print()
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
# The r2 score is  0.9554718030886851
#
# The cross validation score is -15.852906731030748
#
# The mean absolute error is  2.383062226194521
#
# The root mean square error is 1.5437170162288556
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='uniform')
#
# The r2 score is  0.4720834528247777
#
# The cross validation score is 0.7210933971308202
#
# The mean absolute error is  8.275
#
# The root mean square error is 2.876629972728505
#
#
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
# ...

# %%
result=pd.DataFrame({'Model':['LinearRegression','KNeighborsRegressor', 'DecisionTreeRegressor', 'SVR'],'R2score':score,'Cross_val_score':cv,'Mean Squared Error':Mean, 'Root Mean Squared Error': Root})
result
# Out:
#                    Model   R2score  Cross_val_score  Mean Squared Error  \
# 0       LinearRegression  0.955472       -15.852907            2.383062
# 1    KNeighborsRegressor  0.472083         0.721093            8.275000
# 2  DecisionTreeRegressor  0.898910         0.873708            3.916667
# 3                    SVR  0.926596         0.943806            2.554699
#
#    Root Mean Squared Error
# 0                 1.543717
# 1                 2.876630
# 2                 1.979057
# 3                 1.598343

# %% [markdown]
# #as the cross_val_score is too low, so lets try lasso and rigde

# %% [markdown]
# ##LASSO REGRESSION

# %%
def max_r2_score(reg,x,y):
    max_r2score=0
    for r_state in range(42,101):
        train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state,test_size=0.20)
        reg.fit(train_x,train_y)
        pred=reg.predict(test_x)
        r2score=r2_score(test_y,pred)
        print("The r2 score", r2score, "is achieved at r_state", r_state)
        if r2score>max_r2score:
            max_r2score=r2score
            final_r_state=r_state
    print("The maximum r2 score", max_r2score, "is achieved at r_state", final_r_state)
    return final_r_state

# %%
from sklearn.linear_model import Lasso
ls=Lasso()
parameters={'alpha':(0.001,0.01,0.1)}
gdls=GridSearchCV(ls,parameters)
gdls.fit(train_x,train_y)
gdls.best_params_
# Out:
# {'alpha': 0.1}

# %%
ls=Lasso(alpha=0.1)
max_r2_score(ls,x,y)
# Out:
# The r2 score 0.958386465893773 is achieved at r_state 42
# The r2 score 0.9675287027712562 is achieved at r_state 43
# The r2 score 0.9881511677853598 is achieved at r_state 44
# The r2 score 0.9501214477238584 is achieved at r_state 45
# The r2 score 0.9573947953345066 is achieved at r_state 46
# The r2 score 0.9643412092180533 is achieved at r_state 47
# The r2 score 0.988445780382285 is achieved at r_state 48
# The r2 score 0.962493095634375 is achieved at r_state 49
# The r2 score 0.9594286898623148 is achieved at r_state 50
# The r2 score 0.9612086873759965 is achieved at r_state 51
# The r2 score 0.9754956455352033 is achieved at r_state 52
# The r2 score 0.9897171237471875 is achieved at r_state 53
# The r2 score 0.9300759755876887 is achieved at r_state 54
# The r2 score 0.988749788497819 is achieved at r_state 55
# The r2 score 0.9477985804850523 is achieved at r_state 56
# The r2 score 0.9296042099515917 is achieved at r_state 57
# ...

# %%
#Lets check the cross val score
cvscore=cross_val_score(ls,x,y,cv=5,scoring='r2').mean()
print("The cross validation score is", cvscore)
# Out:
# The cross validation score is 0.9629684054004631

# %% [markdown]
# ##RIDGE REGRESSION

# %%
#Lets check the best parameters for ridge
from sklearn.linear_model import Ridge
rd=Ridge()
parameters={'alpha':(0.001,0.01,0.1,1)}
grd=GridSearchCV(rd,parameters)
grd.fit(train_x,train_y)
grd.best_params_
# Out:
# {'alpha': 0.1}

# %%
#Lets check the r2 score for ridge
rd=Ridge(alpha=0.1)
max_r2_score(rd,x,y)
# Out:
# The r2 score 0.8598694977477979 is achieved at r_state 42
# The r2 score 0.8984595571431947 is achieved at r_state 43
# The r2 score 0.9905274249201516 is achieved at r_state 44
# The r2 score 0.9498651190065266 is achieved at r_state 45
# The r2 score 0.9655373029814929 is achieved at r_state 46
# The r2 score 0.9397203663506641 is achieved at r_state 47
# The r2 score 0.9776306430486243 is achieved at r_state 48
# The r2 score 0.9356797017810766 is achieved at r_state 49
# The r2 score 0.9441251022277285 is achieved at r_state 50
# The r2 score 0.9197827278547214 is achieved at r_state 51
# The r2 score 0.9741938514766441 is achieved at r_state 52
# The r2 score 0.9881708478246618 is achieved at r_state 53
# The r2 score 0.907114262013536 is achieved at r_state 54
# The r2 score 0.9899317579119629 is achieved at r_state 55
# The r2 score 0.8884836672591213 is achieved at r_state 56
# The r2 score 0.9574671085197464 is achieved at r_state 57
# ...

# %%
cvscore=cross_val_score(rd,x,y,cv=5,scoring='r2').mean()
print("The cross validation score is", cvscore)
# Out:
# The cross validation score is 0.9455391973330478

# %% [markdown]
# ##ENSEMBLE TECHNIQUES

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
#Selecting the best parameters using GridSearchCV
rf=RandomForestRegressor()
parameters={'n_estimators':(50,100,200,500), 'criterion':('mse','mae')}
gdrf=GridSearchCV(rf,parameters)
gdrf.fit(train_x,train_y)
gdrf.best_params_
# Out:
# {'criterion': 'mae', 'n_estimators': 100}

# %%
#Lets check the r2 score 
rf=RandomForestRegressor(criterion='mae',n_estimators=100)
max_r2_score(rf,x,y)
# Out:
# The r2 score 0.9166897084869082 is achieved at r_state 42
# The r2 score 0.9257281007172743 is achieved at r_state 43
# The r2 score 0.927783283464567 is achieved at r_state 44
# The r2 score 0.849521860204653 is achieved at r_state 45
# The r2 score 0.8007053033658105 is achieved at r_state 46
# The r2 score 0.9079454142386623 is achieved at r_state 47
# The r2 score 0.8886636589519529 is achieved at r_state 48
# The r2 score 0.7889916274401219 is achieved at r_state 49
# The r2 score 0.8198188131664348 is achieved at r_state 50
# The r2 score 0.8725204636606709 is achieved at r_state 51
# The r2 score 0.888322040413997 is achieved at r_state 52
# The r2 score 0.9353576081039502 is achieved at r_state 53
# The r2 score 0.8687761864850707 is achieved at r_state 54
# The r2 score 0.9651223874297958 is achieved at r_state 55
# The r2 score 0.8626538216682647 is achieved at r_state 56
# The r2 score 0.7366904616814708 is achieved at r_state 57
# ...

# %%
#Lets check the cross val score
cvscore=cross_val_score(rf,x,y,cv=5,scoring='r2').mean()
print("The cross validation score is", cvscore)
# Out:
# The cross validation score is 0.9034994418810983

# %% [markdown]
# GradientBoostingRegressor

# %%
#selecting the best parameters 
gb=GradientBoostingRegressor()
parameters={'loss':('ls','lad','huber','quantile'), 'learning_rate':(0.001,0.01,0.1,1), 'n_estimators':(10,50,100,500,1000), 'criterion':('friedman_mse', 'mse', 'mae')}
gdg=GridSearchCV(gb,parameters)                                                                                                                                        
gdg.fit(train_x,train_y)                                                                                                                                         
gdg.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.1,
#  'loss': 'lad',
#  'n_estimators': 1000}

# %%
gb=GradientBoostingRegressor(criterion='friedman_mse',n_estimators=1000,learning_rate=0.01,loss='lad')
max_r2_score(gb,x,y)
# Out:
# The r2 score 0.9405429519891754 is achieved at r_state 42
# The r2 score 0.9531486210858785 is achieved at r_state 43
# The r2 score 0.9653707890547794 is achieved at r_state 44
# The r2 score 0.9627945970166728 is achieved at r_state 45
# The r2 score 0.8994563568644974 is achieved at r_state 46
# The r2 score 0.9397399954363261 is achieved at r_state 47
# The r2 score 0.9308303391693795 is achieved at r_state 48
# The r2 score 0.8823911004644139 is achieved at r_state 49
# The r2 score 0.8789945733561342 is achieved at r_state 50
# The r2 score 0.9455646470065713 is achieved at r_state 51
# The r2 score 0.9374131295943917 is achieved at r_state 52
# The r2 score 0.9509158399569451 is achieved at r_state 53
# The r2 score 0.9444806202177431 is achieved at r_state 54
# The r2 score 0.953429000675763 is achieved at r_state 55
# The r2 score 0.9365386477672504 is achieved at r_state 56
# The r2 score 0.8530083953065019 is achieved at r_state 57
# ...

# %%
#Lets check the cross val score
cvscore=cross_val_score(gb,x,y,cv=5,scoring='r2').mean()
print("The cross validation score is", cvscore)
# Out:
# The cross validation score is 0.9299160930937871

# %% [markdown]
# AdaBoostRegressor

# %%
#selecting the best parameters
ad=AdaBoostRegressor()
parameters={'n_estimators':(10,50,100,200,500),'learning_rate':(0.001,0.01,0.1,1),'loss':('linear','square','exponential')}
gad=GridSearchCV(ad,parameters)
gad.fit(train_x,train_y)
gad.best_params_
# Out:
# {'learning_rate': 1, 'loss': 'square', 'n_estimators': 50}

# %%
#Lets check the r2 score 
ad=AdaBoostRegressor(n_estimators=50,learning_rate=1,loss='square')
max_r2_score(ad,x,y)
# Out:
# The r2 score 0.8858533684882695 is achieved at r_state 42
# The r2 score 0.8898941372452992 is achieved at r_state 43
# The r2 score 0.928766308676521 is achieved at r_state 44
# The r2 score 0.7848401376925409 is achieved at r_state 45
# The r2 score 0.7380534714788057 is achieved at r_state 46
# The r2 score 0.9173020650769271 is achieved at r_state 47
# The r2 score 0.9034017984138232 is achieved at r_state 48
# The r2 score 0.791292377431835 is achieved at r_state 49
# The r2 score 0.7967930468432157 is achieved at r_state 50
# The r2 score 0.8313056588448046 is achieved at r_state 51
# The r2 score 0.8521029114126347 is achieved at r_state 52
# The r2 score 0.9333874240996372 is achieved at r_state 53
# The r2 score 0.8611097121154896 is achieved at r_state 54
# The r2 score 0.9542002282124997 is achieved at r_state 55
# The r2 score 0.8608772111715365 is achieved at r_state 56
# The r2 score 0.6631276294671905 is achieved at r_state 57
# ...

# %%
#Lets check the cross val score
cvscore=cross_val_score(ad,x,y,cv=5,scoring='r2').mean()
print("The cross validation score is", cvscore)
# Out:
# The cross validation score is 0.8966236883928552

# %%
result_L=pd.DataFrame({'Boosters':['Lasso','Ridge','RandomForestRegressor','GradientBoostRegressor','AdaBoostRegressor'],'R2 Score':[0.947,0.919,0.83,0.859,0.823],'Cross_val_score':[0.479,0.292,-0.443,-0.499,-1.32]})
result_L
# Out:
#                  Boosters  R2 Score  Cross_val_score
# 0                   Lasso     0.947            0.479
# 1                   Ridge     0.919            0.292
# 2   RandomForestRegressor     0.830           -0.443
# 3  GradientBoostRegressor     0.859           -0.499
# 4       AdaBoostRegressor     0.823           -1.320

# %%
result
# Out:
#                    Model   R2score  Cross_val_score  Mean Squared Error  \
# 0       LinearRegression  0.955472       -15.852907            2.383062
# 1    KNeighborsRegressor  0.472083         0.721093            8.275000
# 2  DecisionTreeRegressor  0.898910         0.873708            3.916667
# 3                    SVR  0.926596         0.943806            2.554699
#
#    Root Mean Squared Error
# 0                 1.543717
# 1                 2.876630
# 2                 1.979057
# 3                 1.598343

# %%
#Finalising the model
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=75,test_size=0.20)
ls=Lasso(alpha=0.1)
ls.fit(train_x,train_y)
pred=ls.predict(test_x)
r2score=r2_score(test_y,pred)
cv=cross_val_score(ls,x,y,cv=5,scoring='r2').mean()
print("The accuracy score is", r2score)
print("The cross val score is", cv)
pd.DataFrame(pred).to_csv("Project2_Baseballpredictions.csv")
# Out:
# The accuracy score is 0.9529720303270593
# The cross val score is 0.9629684054004631

# %%
#Finalising the model
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=75,test_size=0.20)
sv=SVR(C=10,kernel='linear')
sv.fit(train_x,train_y)
pred=sv.predict(test_x)
r2score=r2_score(test_y,pred)
cv=cross_val_score(sv,x,y,cv=5,scoring='r2').mean()
print("The accuracy score is", r2score)
print("The cross val score is", cv)
pd.DataFrame(pred).to_csv("Project2_Baseballpredictions.csv")
# Out:
# The accuracy score is 0.9271612764776852
# The cross val score is 0.9438064977226694

# %% [markdown]
# #hence lasso is the best model for this dataset

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(ls,"Covid_USA.pkl")
# Out:
# ['Covid_USA.pkl']
